# %%
import cv2
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import os

# %%
# 1) 0 - 60*5
# 2) 4*60*60 - 4*60*60 + 60*5
# 3) 8*60*60 - 8*60*60 + 60*5
# 4) 12*60*60 - 12*60*60 + 60*5
# 5) 16*60*60 - 16*60*60 + 60*5
# 6) 20*60*60 - 20*60*60 + 60*5

# %%
video_path = '/storage/vskovoroda/Netris/'

# %%
ffmpeg_extract_subclip(video_path+'vidos.mp4', 57433, 57433+62, targetname="test.mp4")
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful

# %%
for ind, i in enumerate(sorted(os.listdir(video_path+'train_all/labels'))):
    if i[0]!='f':
        continue
    os.rename(video_path+'train_all/labels/'+i, video_path+'train_all/labels/6_'+i)
    if ind % 100 == 0:
        print(ind)
# Out:
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400

# %%
for ind, i in enumerate(sorted(os.listdir(video_path+'1/labels'))):
    os.rename(video_path+'1/labels/'+i, video_path+'1/labels/new_'+i)
    if ind % 100 == 0:
        print(ind)
# Out:
# 0
# 100
# 200
# 300
# 400

# %%
for i in sorted(os.listdir(video_path+'train_all/labels')):
    if i[0] == '6':
        print(i)
# Out:
# 6_frame_000000.txt
# 6_frame_000001.txt
# 6_frame_000002.txt
# 6_frame_000003.txt
# 6_frame_000004.txt
# 6_frame_000005.txt
# 6_frame_000006.txt
# 6_frame_000007.txt
# 6_frame_000008.txt
# 6_frame_000009.txt
# 6_frame_000010.txt
# 6_frame_000011.txt
# 6_frame_000012.txt
# 6_frame_000013.txt
# 6_frame_000014.txt
# 6_frame_000015.txt
# 6_frame_000016.txt
# 6_frame_000017.txt
# 6_frame_000018.txt
# 6_frame_000019.txt
# 6_frame_000020.txt
# 6_frame_000021.txt
# 6_frame_000022.txt
# 6_frame_000023.txt
# 6_frame_000024.txt
# 6_frame_000025.txt
# 6_frame_000026.txt
# 6_frame_000027.txt
# 6_frame_000028.txt
# 6_frame_000029.txt
# 6_frame_000030.txt
# 6_frame_000031.txt
# 6_frame_000032.txt
# 6_frame_000033.txt
# 6_frame_000034.txt
# 6_frame_000035.txt
# 6_frame_000036.txt
# 6_frame_000037.txt
# 6_frame_000038.txt
# 6_frame_000039.txt
# 6_frame_000040.txt
# 6_frame_000041.txt
# 6_frame_000042.txt
# 6_frame_000043.txt
# 6_frame_000044.txt
# 6_frame_000045.txt
# 6_frame_000046.txt
# ...

# %%
with open(video_path+'train_all/labels/new_frame_000494.txt', 'r+') as file:
    print(file.read())
# Out:
# 0 0.131156 0.571858 0.046047 0.097188
# 1 0.090043 0.578576 0.024641 0.038111
# 3 0.780162 0.433278 0.099129 0.254472
# 0 0.883156 0.422184 0.024078 0.055201
# 2 0.899305 0.446486 0.011617 0.031778
# 3 0.982006 0.452101 0.035246 0.289785

# %%
with open(video_path+'train_all/labels/new_frame_000000.txt', 'r+') as file:
    print(file.read())
# Out:
# 2 0.074822 0.555399 0.035879 0.033951
# 0 0.126404 0.573861 0.026676 0.091111
# 1 0.084502 0.609931 0.020301 0.048264
# 1 0.674240 0.465118 0.016996 0.031778
# 3 0.757094 0.436667 0.051828 0.253889
# 0 0.883156 0.429139 0.024078 0.041292
# 2 0.899305 0.446486 0.011617 0.031778
# 3 0.982006 0.452101 0.035246 0.289785

# %%
sorted(os.listdir(video_path+'train6/labels'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [84], line 1
# ----> 1 sorted(os.listdir(video_path+'train6/labels'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/storage/vskovoroda/Netris/train6/labels'

# %%
with open(video_path+'train6/labels/'+i, 'r+', encoding='utf-8') as file:
        string = file.read().split()
        # string = string
        file.truncate(0)
        for clss in range(0, len(string), 5):
            try:
                string[clss] = change[string[clss]]
                file.write(' '.join(string[clss:clss+5])+'\n')
            except:
                print(string)
                break
        print(string)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [82], line 1
# ----> 1 with open(video_path+'train6/labels/'+i, 'r+', encoding='utf-8') as file:
#       2         string = file.read().split()
#       3         string = string[:len(string)]
#
# File ~/miniconda3/envs/tf-gpu/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/storage/vskovoroda/Netris/train6/labels/new_frame_000494.txt'

# %%
for ind, i in enumerate(sorted(os.listdir(video_path+'train_all/labels'))):
    if i[0] != '6':
        continue
    with open(video_path+'train_all/labels/'+i, 'r+') as file:
        string = file.read()
        # string=string[:len(string)//2]
        open(video_path+'train_all/labels/'+i, 'w').close()
        file.write(string)

# %%
change = {
    '0':'2',
    '1':'0',
    '2':'3',
    '3':'1'
}
for ind, i in enumerate(sorted(os.listdir(video_path+'6labels'))):
    if i[0] != 'f':
        continue
    with open(video_path+'6labels/'+i, 'r') as file:
        string = file.read().split()
        f = open(video_path+'train_all/labels/6_'+i, 'w')
        for clss in range(0, len(string), 5):
            try:
                string[clss] = change[string[clss]]
                f.write(' '.join(string[clss:clss+5])+'\n')
            except:
                print(string)
                break
        f.close()
    if ind % 100 == 0:
        print(ind)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800

# %%
string[0]='5'

# %%
os.listdir(video_path+'train_all/images')
# Out:
# ['1_frame_001425.png',
#  '3_frame_000974.png',
#  '1_frame_001236.png',
#  '1_frame_000642.png',
#  '1_frame_000637.png',
#  '1_frame_000130.png',
#  '3_frame_001692.png',
#  '1_frame_000392.png',
#  '1_frame_001574.png',
#  '1_frame_001136.png',
#  '3_frame_000514.png',
#  '1_frame_000527.png',
#  '1_frame_000243.png',
#  '3_frame_001404.png',
#  '3_frame_001594.png',
#  '3_frame_001717.png',
#  '3_frame_000701.png',
#  '3_frame_001062.png',
#  '1_frame_001568.png',
#  '1_frame_000019.png',
#  '3_frame_000123.png',
#  '1_frame_000099.png',
#  '1_frame_000889.png',
#  '1_frame_000768.png',
#  '3_frame_000759.png',
#  '3_frame_000137.png',
#  '1_frame_000660.png',
#  '1_frame_000447.png',
#  '3_frame_000645.png',
#  '3_frame_000917.png',
#  '1_frame_001012.png',
#  '1_frame_001737.png',
#  '1_frame_000493.png',
#  '1_frame_000763.png',
#  '3_frame_000060.png',
#  '1_frame_000459.png',
#  '3_frame_000197.png',
#  '1_frame_000377.png',
#  '1_frame_000401.png',
#  '1_frame_000328.png',
# ...

# %%
cap = cv2.VideoCapture('test.mp4')
ind = 0
while True:
    ret, frame = cap.read()
    if not ret:
        print('fin')
        break
    name = 'frame_'+'0'*(6-len(str(ind)))+str(ind) + '.png'
    cv2.imwrite('/storage/vskovoroda/Netris/vvvv/images/'+name, frame)
    if ind % 100 == 0:
        print(ind)
    ind += 1
# Out:
# 0
# 100
# 200
# 300
# fin

# %%
cap = cv2.VideoCapture('1.mp4')
ind = 0
while True:
    ret, frame = cap.read()
    if not ret:
        print('fin')
        break
    name = 'frame_'+'0'*(6-len(str(ind)))+str(ind) + '.png'
    cv2.imwrite('/storage/vskovoroda/Netris/1/images/'+name, frame)
    if ind % 100 == 0:
        print(ind)
    ind += 1
# Out:
# 0
# 100
# 200
# 300
# 400
# fin
